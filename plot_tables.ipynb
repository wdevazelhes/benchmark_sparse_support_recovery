# %%
import pandas as pd

score_name = "objective_f1score"

# create a pandas dataframe from the results
df = pd.read_parquet('./outputs/benchopt_run_2024-05-23_17h34m07.parquet')
df = df[['objective_name', 'solver_name', 'data_name', score_name]]
# df = 
# df.drop_duplicates(inplace=True)
# pivot the dataframe to show the score for each algorithm and dataset
pivot_df = df.pivot(index="solver_name", columns="data_name", values=score_name)

# print the pivot table
print(pivot_df)
# Out:
# data_name                                           deconvolution[k=5,random_state=None,snr=10.0]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.451791
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.936070
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.935419
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.739017
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.828828
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.936001
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.979874
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.739000
#
# data_name                                           lattice[k=10,random_state=None,semi_simulated=True,snr=10.0]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                          -1.141354
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.977663
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.138523
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.942063
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                          -2.429538
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.158239
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.942063
#
# data_name                                           lattice[k=None,random_state=None,semi_simulated=False,snr=None]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
#
# data_name                                           ode[degree=3,dt=0.01,duration=1,noise_ratio=0.001,seed=None,system=Lorenz]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
#
# data_name                                           simulated[density=0.1,n_features=50,n_samples=30,random_state=None,rho=0.9,snr=10.0]
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                          -0.228405
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.454413
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.000000
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.870134
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.647402
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.000000

# %%
pivot_df
# Out:
# data_name                                           deconvolution[k=5,random_state=None,snr=10.0]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.451791
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.936070
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.935419
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.739017
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.828828
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.936001
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.979874
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.739000
#
# data_name                                           lattice[k=10,random_state=None,semi_simulated=True,snr=10.0]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                          -1.141354
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.977663
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.138523
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.942063
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                          -2.429538
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.158239
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.942063
#
# data_name                                           lattice[k=None,random_state=None,semi_simulated=False,snr=None]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
#
# data_name                                           ode[degree=3,dt=0.01,duration=1,noise_ratio=0.001,seed=None,system=Lorenz]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
#
# data_name                                           simulated[density=0.1,n_features=50,n_samples=30,random_state=None,rho=0.9,snr=10.0]
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                          -0.228405
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.454413
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.000000
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.870134
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.647402
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.000000
