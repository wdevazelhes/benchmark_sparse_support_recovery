# %%
import pandas as pd

score_name = "objective_f1score"

# create a pandas dataframe from the results
df = pd.read_parquet('./outputs/benchopt_run_2024-05-15_22h09m38.parquet')
df = df[['objective_name', 'solver_name', 'data_name', score_name]]
# df = 
# df.drop_duplicates(inplace=True)
# pivot the dataframe to show the score for each algorithm and dataset
pivot_df = df.pivot(index="solver_name", columns="data_name", values=score_name)

# print the pivot table
print(pivot_df)
# Out:
# data_name                                           deconvolution[k=5,random_state=None,snr=10.0]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.805287
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.967129
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       1.261184
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.738734
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.998543
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       1.260749
#
# data_name                                           lattice[k=10,random_state=None,semi_simulated=True,snr=10.0]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.562176
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.960543
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.023785
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.770179
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.991709
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.023785
#
# data_name                                           lattice[k=None,random_state=None,semi_simulated=False,snr=None]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
#
# data_name                                           ode[degree=3,dt=0.01,duration=1,noise_ratio=0.001,seed=None,system=Lorenz]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
#
# data_name                                           simulated[density=0.1,n_features=50,n_samples=30,random_state=None,rho=0.9,snr=10.0]
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                          -0.780589
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                          -3.323738
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.125171
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           6.523668
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                         -47.495641
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.125171

# %%
pivot_df
# Out:
# data_name                                           deconvolution[k=5,random_state=None,snr=10.0]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.805287
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.967129
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       1.261184
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.738734
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       0.998543
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                       1.260749
#
# data_name                                           lattice[k=10,random_state=None,semi_simulated=True,snr=10.0]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.562176
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.960543
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.023785
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.770179
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           0.991709
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.023785
#
# data_name                                           lattice[k=None,random_state=None,semi_simulated=False,snr=None]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                NaN
#
# data_name                                           ode[degree=3,dt=0.01,duration=1,noise_ratio=0.001,seed=None,system=Lorenz]  \
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                                0.0
#
# data_name                                           simulated[density=0.1,n_features=50,n_samples=30,random_state=None,rho=0.9,snr=10.0]
# solver_name
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                          -0.780589
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                          -3.323738
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.125171
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           6.523668
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                         -47.495641
# skglm[alphaNum=1000,alphaRatio=1e-10,debiasing_...                                           1.125171
